# %% [markdown]
# # Read hw1.csv file and plot figure for visulization

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hw1.csv')

# %%
df
# Out:
#      report_id hospital_id  transfer_idx  disease  disease2  death_1m  age  \
# 0     R0001190    H0032093             2    False        -1     False   91
# 1     R0001575    H0082188             6    False        -1     False   64
# 2     R0002763    H0031789             2    False        -1     False   61
# 3     R0002510    H0092355             6    False        -1     False   52
# 4     R0001296    H0088464             3     True         0     False   65
# ...        ...         ...           ...      ...       ...       ...  ...
# 3065  R0002152    H0019197             1     True         2     False   90
# 3066  R0002901    H0024731             1     True         2      True   71
# 3067  R0000675    H0091312             0     True         1     False   45
# 3068  R0000638    H0092408             1    False         0     False   50
# 3069  R0000231    H0088047             0     True         1     False   93
#
#       sex  weight  height
# 0       1      40     153
# 1       1      67     181
# 2       1      56     151
# 3       0      47     176
# 4       0      64     157
# ...   ...     ...     ...
# 3065    1      51     144
# 3066    1      50     155
# 3067    1      52     174
# 3068    1      40     157
# 3069    1      85     178
#
# [3070 rows x 10 columns]

# %%
df2 = df.merge(df,how='inner', left_index=True, right_index=True)

# %%
df2
# Out:
#      report_id_x hospital_id_x  transfer_idx_x  disease_x  disease2_x  \
# 0       R0001190      H0032093               2      False          -1
# 1       R0001575      H0082188               6      False          -1
# 2       R0002763      H0031789               2      False          -1
# 3       R0002510      H0092355               6      False          -1
# 4       R0001296      H0088464               3       True           0
# ...          ...           ...             ...        ...         ...
# 3065    R0002152      H0019197               1       True           2
# 3066    R0002901      H0024731               1       True           2
# 3067    R0000675      H0091312               0       True           1
# 3068    R0000638      H0092408               1      False           0
# 3069    R0000231      H0088047               0       True           1
#
#       death_1m_x  age_x  sex_x  weight_x  height_x  ...  transfer_idx_y  \
# 0          False     91      1        40       153  ...               2
# 1          False     64      1        67       181  ...               6
# 2          False     61      1        56       151  ...               2
# 3          False     52      0        47       176  ...               6
# 4          False     65      0        64       157  ...               3
# ...          ...    ...    ...       ...       ...  ...             ...
# 3065       False     90      1        51       144  ...               1
# 3066        True     71      1        50       155  ...               1
# 3067       False     45      1        52       174  ...               0
# 3068       False     50      1        40       157  ...               1
# 3069       False     93      1        85       178  ...               0
#
#       disease_y disease2_y death_1m_y  age_y  sex_y  weight_y  height_y  \
# 0         False         -1      False     91      1        40       153
# 1         False         -1      False     64      1        67       181
# 2         False         -1      False     61      1        56       151
# 3         False         -1      False     52      0        47       176
# 4          True          0      False     65      0        64       157
# ...         ...        ...        ...    ...    ...       ...       ...
# 3065       True          2      False     90      1        51       144
# 3066       True          2       True     71      1        50       155
# 3067       True          1      False     45      1        52       174
# 3068      False          0      False     50      1        40       157
# 3069       True          1      False     93      1        85       178
#
#           BMI_y     BMI2_y
# 0     17.087445  17.087445
# 1     20.451146  20.451146
# 2     24.560326  24.560326
# 3     15.173037  15.173037
# 4     25.964542  25.964542
# ...         ...        ...
# 3065  24.594907  24.594907
# 3066  20.811655  20.811655
# 3067  17.175320  17.175320
# 3068  16.227839  16.227839
# 3069  26.827421  26.827421
#
# [3070 rows x 24 columns]

# %%
pd.concat([df,df])
# Out:
#      report_id hospital_id  transfer_idx  disease  disease2  death_1m  age  \
# 0     R0001190    H0032093             2    False        -1     False   91
# 1     R0001575    H0082188             6    False        -1     False   64
# 2     R0002763    H0031789             2    False        -1     False   61
# 3     R0002510    H0092355             6    False        -1     False   52
# 4     R0001296    H0088464             3     True         0     False   65
# ...        ...         ...           ...      ...       ...       ...  ...
# 3065  R0002152    H0019197             1     True         2     False   90
# 3066  R0002901    H0024731             1     True         2      True   71
# 3067  R0000675    H0091312             0     True         1     False   45
# 3068  R0000638    H0092408             1    False         0     False   50
# 3069  R0000231    H0088047             0     True         1     False   93
#
#       sex  weight  height        BMI       BMI2
# 0       1      40     153  17.087445  17.087445
# 1       1      67     181  20.451146  20.451146
# 2       1      56     151  24.560326  24.560326
# 3       0      47     176  15.173037  15.173037
# 4       0      64     157  25.964542  25.964542
# ...   ...     ...     ...        ...        ...
# 3065    1      51     144  24.594907  24.594907
# 3066    1      50     155  20.811655  20.811655
# 3067    1      52     174  17.175320  17.175320
# 3068    1      40     157  16.227839  16.227839
# 3069    1      85     178  26.827421  26.827421
#
# [6140 rows x 12 columns]

# %% [markdown]
# #### Q1: Calculate how many unique **report_id** and **hospital_id** ?
#
# **HINT: np.unique**

# %%
# Method 1: np.unique
print(len(np.unique(df['report_id'])))

# Method 2: pd.unique
print(len(pd.unique(df['report_id'])))

# Method 3: pd.Series.unique
print(len(df['report_id'].unique()))
# Out:
# 1945
# 1945
# 1945

# %%
len(np.unique(df['report_id'].values))
# Out:
# 1945

# %%
len(np.unique(df['hospital_id'].values))
# Out:
# 3023

# %% [markdown]
# #### Q2: Create a new column named **BMI**
#
# **HINT**: https://zh.wikipedia.org/wiki/%E8%BA%AB%E9%AB%98%E9%AB%94%E9%87%8D%E6%8C%87%E6%95%B8

# %%
BMI = []
for each_column in range( len(df) ) :
    bmi = df.loc[each_column]['weight'] / ( (df.loc[each_column]['height']*0.01)**2 )
    BMI.append(bmi)
    
df['BMI']=BMI

# %%
df['BMI2'] = df['weight'] / (df['height'] / 100.) ** 2

# %%
df
# Out:
#      report_id hospital_id  transfer_idx  disease  disease2  death_1m  age  \
# 0     R0001190    H0032093             2    False        -1     False   91
# 1     R0001575    H0082188             6    False        -1     False   64
# 2     R0002763    H0031789             2    False        -1     False   61
# 3     R0002510    H0092355             6    False        -1     False   52
# 4     R0001296    H0088464             3     True         0     False   65
# ...        ...         ...           ...      ...       ...       ...  ...
# 3065  R0002152    H0019197             1     True         2     False   90
# 3066  R0002901    H0024731             1     True         2      True   71
# 3067  R0000675    H0091312             0     True         1     False   45
# 3068  R0000638    H0092408             1    False         0     False   50
# 3069  R0000231    H0088047             0     True         1     False   93
#
#       sex  weight  height        BMI       BMI2
# 0       1      40     153  17.087445  17.087445
# 1       1      67     181  20.451146  20.451146
# 2       1      56     151  24.560326  24.560326
# 3       0      47     176  15.173037  15.173037
# 4       0      64     157  25.964542  25.964542
# ...   ...     ...     ...        ...        ...
# 3065    1      51     144  24.594907  24.594907
# 3066    1      50     155  20.811655  20.811655
# 3067    1      52     174  17.175320  17.175320
# 3068    1      40     157  16.227839  16.227839
# 3069    1      85     178  26.827421  26.827421
#
# [3070 rows x 12 columns]

# %% [markdown]
# #### Q3: Use Matplotlib to plot figures for the columns, figure type is up to you (bar, plot, histogram , scatter ... etc)

# %%
import matplotlib.pyplot as plt

# %%
# 1. report_id, hospital_id, transfer_idx for unique values
unqiue_value, counts = np.unique(df['transfer_idx'], return_counts=True)
plt.bar(unqiue_value, counts)
plt.show()

# %%
plt.hist(df['age'])
# Out:
# (array([  4.,  44., 149., 381., 545., 603., 632., 493., 199.,  20.]),
#  array([ 19. ,  27.6,  36.2,  44.8,  53.4,  62. ,  70.6,  79.2,  87.8,
#          96.4, 105. ]),
#  <BarContainer object of 10 artists>)

# %%
# Scatter: BMI v.s AGE
plt.scatter(df['BMI'], df['age'])
plt.xlabel('BMI'); plt.ylabel('age')
plt.show()

# %%
plt.scatter(df['height'],df['weight'])
